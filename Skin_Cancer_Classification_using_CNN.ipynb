# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import math
import os
import cv2
from PIL import Image
import numpy as np
from keras import layers
from tensorflow.keras.applications import ResNet50,MobileNet, DenseNet201, InceptionV3, NASNetLarge, InceptionResNetV2, NASNetMobile
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools
# %matplotlib inline

# %% [markdown]
# # Loading & Preprocessing

# %%
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".jpg":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

benign_train = np.array(Dataset_loader('/content/drive/MyDrive/Scin Cancer/ISIC 2016/Training/benign',224))
malign_train = np.array(Dataset_loader('/content/drive/MyDrive/Scin Cancer/ISIC 2016/Training/malignant',224))
benign_val = np.array(Dataset_loader('/content/drive/MyDrive/Scin Cancer/ISIC 2016/Validation/benign',224))
malign_val = np.array(Dataset_loader('/content/drive/MyDrive/Scin Cancer/ISIC 2016/Validation/malignant',224))
benign_test = np.array(Dataset_loader('/content/drive/MyDrive/Scin Cancer/ISIC 2016/Testing/benign',224))
malign_test = np.array(Dataset_loader('/content/drive/MyDrive/Scin Cancer/ISIC 2016/Testing/malignant',224))
# Out:
# 100%|██████████| 582/582 [02:44<00:00,  3.54it/s]
# 100%|██████████| 138/138 [00:36<00:00,  3.73it/s]
# 100%|██████████| 145/145 [00:50<00:00,  2.86it/s]
# 100%|██████████| 35/35 [00:08<00:00,  3.93it/s]
# 100%|██████████| 304/304 [01:24<00:00,  3.61it/s]
# 100%|██████████| 75/75 [00:16<00:00,  4.42it/s]

# %% [markdown]
# # Create Label

# %%
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_val_label = np.zeros(len(benign_val))
malign_val_label = np.ones(len(malign_val))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test)) 

X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_val = np.concatenate((benign_val, malign_val), axis = 0)
Y_val = np.concatenate((benign_val_label, malign_val_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_val.shape)
print(Y_val.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (720, 224, 224, 3)
# (720,)
# (180, 224, 224, 3)
# (180,)
# (379, 224, 224, 3)
# (379,)

# %%
# Oversample and plot imbalanced dataset with SMOTE
from collections import Counter
from imblearn.over_sampling import SMOTE

# summarize class distribution
counter = Counter(Y_train)
print(counter)
# Out:
# Counter({0.0: 582, 1.0: 138})
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# #SMOTE

# %%
sm = SMOTE(random_state=42)
    
train_rows=len(X_train)
X_train = X_train.reshape(train_rows,-1)
print(X_train.shape)

X_train, Y_train = sm.fit_resample(X_train, Y_train)
X_train = X_train.reshape(-1,224,224,3)

print(X_train.shape)
# Out:
# (1164, 150528)
# (1164, 224, 224, 3)

# %%
# summarize the new class distribution
counter = Counter(Y_train)
print(counter)
# Out:
# Counter({0.0: 582, 1.0: 582})

# %%
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

s = np.arange(X_val.shape[0])
np.random.shuffle(s)
X_val = X_val[s]
Y_val = Y_val[s]

s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

Y_train = to_categorical(Y_train, num_classes= 2)
Y_val = to_categorical(Y_val, num_classes= 2) 
Y_test = to_categorical(Y_test, num_classes= 2)

# %% [markdown]
# # Display Some Images

# %%
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 3

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(X_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# # Data Generator

# %%
BATCH_SIZE = 64

train_generator = ImageDataGenerator(
        zoom_range=2, 
        rotation_range = 90,
        horizontal_flip=True, 
        vertical_flip=True, 
    )

# %% [markdown]
# # Model: ResNet50

# %%
def build_model(backbone, lr=5e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy']
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 2)                 4098
# =================================================================
# Total params: 23,600,002
# Trainable params: 23,542,786
# Non-trainable params: 57,216
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

filepath="/content/drive/MyDrive/Scin Cancer/ISIC 2016/weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# # Training & Evaluation

# %%
history = model.fit_generator(
    train_generator.flow(X_train, Y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=X_train.shape[0] / BATCH_SIZE,
    epochs=100,
    validation_data=(X_val, Y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 18/18 [==============================] - 71s 2s/step - loss: 0.5582 - accuracy: 0.7337 - val_loss: 0.5250 - val_accuracy: 0.8111
#
# Epoch 00001: val_accuracy improved from -inf to 0.81111, saving model to /content/drive/MyDrive/Scin Cancer/ISIC 2016/weights.best.hdf5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/100
# 18/18 [==============================] - 28s 1s/step - loss: 0.4192 - accuracy: 0.8290 - val_loss: 0.8293 - val_accuracy: 0.8167
#
# Epoch 00002: val_accuracy improved from 0.81111 to 0.81667, saving model to /content/drive/MyDrive/Scin Cancer/ISIC 2016/weights.best.hdf5
# Epoch 3/100
# 18/18 [==============================] - 28s 1s/step - loss: 0.3849 - accuracy: 0.8625 - val_loss: 1.4266 - val_accuracy: 0.8111
#
# Epoch 00003: val_accuracy did not improve from 0.81667
# Epoch 4/100
# 18/18 [==============================] - 27s 2s/step - loss: 0.3972 - accuracy: 0.8273 - val_loss: 0.9785 - val_accuracy: 0.8222
#
# Epoch 00004: val_accuracy improved from 0.81667 to 0.82222, saving model to /content/drive/MyDrive/Scin Cancer/ISIC 2016/weights.best.hdf5
# Epoch 5/100
# 18/18 [==============================] - 27s 2s/step - loss: 0.3200 - accuracy: 0.8651 - val_loss: 0.9236 - val_accuracy: 0.8389
#
# Epoch 00005: val_accuracy improved from 0.82222 to 0.83889, saving model to /content/drive/MyDrive/Scin Cancer/ISIC 2016/weights.best.hdf5
# Epoch 6/100
# 18/18 [==============================] - 28s 1s/step - loss: 0.3400 - accuracy: 0.8548 - val_loss: 1.0406 - val_accuracy: 0.8278
#
# Epoch 00006: val_accuracy did not improve from 0.83889
# Epoch 7/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.3115 - accuracy: 0.8814 - val_loss: 1.3426 - val_accuracy: 0.8056
#
# Epoch 00007: val_accuracy did not improve from 0.83889
# Epoch 8/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.3104 - accuracy: 0.8643 - val_loss: 1.7608 - val_accuracy: 0.8167
#
# Epoch 00008: val_accuracy did not improve from 0.83889
# Epoch 9/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.3054 - accuracy: 0.8703 - val_loss: 1.0331 - val_accuracy: 0.8167
#
# Epoch 00009: val_accuracy did not improve from 0.83889
# Epoch 10/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2881 - accuracy: 0.8780 - val_loss: 1.2686 - val_accuracy: 0.7889
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
#
# Epoch 00010: val_accuracy did not improve from 0.83889
# Epoch 11/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2545 - accuracy: 0.8814 - val_loss: 1.0649 - val_accuracy: 0.7778
#
# Epoch 00011: val_accuracy did not improve from 0.83889
# Epoch 12/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2830 - accuracy: 0.8823 - val_loss: 0.8701 - val_accuracy: 0.7944
#
# Epoch 00012: val_accuracy did not improve from 0.83889
# Epoch 13/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2304 - accuracy: 0.8935 - val_loss: 0.9461 - val_accuracy: 0.8000
#
# Epoch 00013: val_accuracy did not improve from 0.83889
# Epoch 14/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2541 - accuracy: 0.8866 - val_loss: 0.9497 - val_accuracy: 0.7944
#
# Epoch 00014: val_accuracy did not improve from 0.83889
# Epoch 15/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2398 - accuracy: 0.8935 - val_loss: 0.7129 - val_accuracy: 0.8000
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
#
# Epoch 00015: val_accuracy did not improve from 0.83889
# Epoch 16/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2485 - accuracy: 0.8875 - val_loss: 0.7476 - val_accuracy: 0.8000
#
# Epoch 00016: val_accuracy did not improve from 0.83889
# Epoch 17/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2297 - accuracy: 0.9046 - val_loss: 0.7243 - val_accuracy: 0.8056
#
# Epoch 00017: val_accuracy did not improve from 0.83889
# Epoch 18/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2394 - accuracy: 0.8943 - val_loss: 0.7195 - val_accuracy: 0.8056
#
# Epoch 00018: val_accuracy did not improve from 0.83889
# Epoch 19/100
# 18/18 [==============================] - 27s 2s/step - loss: 0.2427 - accuracy: 0.8883 - val_loss: 0.7058 - val_accuracy: 0.8056
#
# Epoch 00019: val_accuracy did not improve from 0.83889
# Epoch 20/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2314 - accuracy: 0.8935 - val_loss: 0.7036 - val_accuracy: 0.8000
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
#
# Epoch 00020: val_accuracy did not improve from 0.83889
# Epoch 21/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2287 - accuracy: 0.9089 - val_loss: 0.6953 - val_accuracy: 0.8000
#
# Epoch 00021: val_accuracy did not improve from 0.83889
# Epoch 22/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2172 - accuracy: 0.8978 - val_loss: 0.6794 - val_accuracy: 0.8111
#
# Epoch 00022: val_accuracy did not improve from 0.83889
# Epoch 23/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2284 - accuracy: 0.9046 - val_loss: 0.6732 - val_accuracy: 0.8111
#
# Epoch 00023: val_accuracy did not improve from 0.83889
# Epoch 24/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2645 - accuracy: 0.8832 - val_loss: 0.6669 - val_accuracy: 0.8056
#
# Epoch 00024: val_accuracy did not improve from 0.83889
# Epoch 25/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2264 - accuracy: 0.9098 - val_loss: 0.6628 - val_accuracy: 0.8056
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
#
# Epoch 00025: val_accuracy did not improve from 0.83889
# Epoch 26/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2274 - accuracy: 0.8943 - val_loss: 0.6601 - val_accuracy: 0.8056
#
# Epoch 00026: val_accuracy did not improve from 0.83889
# Epoch 27/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2374 - accuracy: 0.8995 - val_loss: 0.6565 - val_accuracy: 0.8056
#
# Epoch 00027: val_accuracy did not improve from 0.83889
# Epoch 28/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2251 - accuracy: 0.9046 - val_loss: 0.6574 - val_accuracy: 0.8056
#
# Epoch 00028: val_accuracy did not improve from 0.83889
# Epoch 29/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2254 - accuracy: 0.8918 - val_loss: 0.6517 - val_accuracy: 0.8056
#
# Epoch 00029: val_accuracy did not improve from 0.83889
# Epoch 30/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2393 - accuracy: 0.8943 - val_loss: 0.6502 - val_accuracy: 0.8056
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 00030: val_accuracy did not improve from 0.83889
# Epoch 31/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2421 - accuracy: 0.8866 - val_loss: 0.6555 - val_accuracy: 0.8056
#
# Epoch 00031: val_accuracy did not improve from 0.83889
# Epoch 32/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2289 - accuracy: 0.8978 - val_loss: 0.6561 - val_accuracy: 0.8056
#
# Epoch 00032: val_accuracy did not improve from 0.83889
# Epoch 33/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2378 - accuracy: 0.8935 - val_loss: 0.6603 - val_accuracy: 0.8000
#
# Epoch 00033: val_accuracy did not improve from 0.83889
# Epoch 34/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2328 - accuracy: 0.9029 - val_loss: 0.6618 - val_accuracy: 0.8000
#
# Epoch 00034: val_accuracy did not improve from 0.83889
# Epoch 35/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2344 - accuracy: 0.8935 - val_loss: 0.6587 - val_accuracy: 0.8000
#
# Epoch 00035: val_accuracy did not improve from 0.83889
# Epoch 36/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2206 - accuracy: 0.9081 - val_loss: 0.6590 - val_accuracy: 0.8000
#
# Epoch 00036: val_accuracy did not improve from 0.83889
# Epoch 37/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2527 - accuracy: 0.8986 - val_loss: 0.6668 - val_accuracy: 0.8000
#
# Epoch 00037: val_accuracy did not improve from 0.83889
# Epoch 38/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2214 - accuracy: 0.9072 - val_loss: 0.6681 - val_accuracy: 0.8000
#
# Epoch 00038: val_accuracy did not improve from 0.83889
# Epoch 39/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2257 - accuracy: 0.9038 - val_loss: 0.6677 - val_accuracy: 0.8000
#
# Epoch 00039: val_accuracy did not improve from 0.83889
# Epoch 40/100
# 18/18 [==============================] - 27s 2s/step - loss: 0.2497 - accuracy: 0.8943 - val_loss: 0.6677 - val_accuracy: 0.8000
#
# Epoch 00040: val_accuracy did not improve from 0.83889
# Epoch 41/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2404 - accuracy: 0.8918 - val_loss: 0.6698 - val_accuracy: 0.8056
#
# Epoch 00041: val_accuracy did not improve from 0.83889
# Epoch 42/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2507 - accuracy: 0.8952 - val_loss: 0.6685 - val_accuracy: 0.8056
#
# Epoch 00042: val_accuracy did not improve from 0.83889
# Epoch 43/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2405 - accuracy: 0.8995 - val_loss: 0.6647 - val_accuracy: 0.8000
#
# Epoch 00043: val_accuracy did not improve from 0.83889
# Epoch 44/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2332 - accuracy: 0.9029 - val_loss: 0.6611 - val_accuracy: 0.8000
#
# Epoch 00044: val_accuracy did not improve from 0.83889
# Epoch 45/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2252 - accuracy: 0.9072 - val_loss: 0.6586 - val_accuracy: 0.8000
#
# Epoch 00045: val_accuracy did not improve from 0.83889
# Epoch 46/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2141 - accuracy: 0.9046 - val_loss: 0.6633 - val_accuracy: 0.8000
#
# Epoch 00046: val_accuracy did not improve from 0.83889
# Epoch 47/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2281 - accuracy: 0.9081 - val_loss: 0.6595 - val_accuracy: 0.8000
#
# Epoch 00047: val_accuracy did not improve from 0.83889
# Epoch 48/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2394 - accuracy: 0.8943 - val_loss: 0.6617 - val_accuracy: 0.8000
#
# Epoch 00048: val_accuracy did not improve from 0.83889
# Epoch 49/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2194 - accuracy: 0.9012 - val_loss: 0.6648 - val_accuracy: 0.8000
#
# Epoch 00049: val_accuracy did not improve from 0.83889
# Epoch 50/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2385 - accuracy: 0.8969 - val_loss: 0.6663 - val_accuracy: 0.8000
#
# Epoch 00050: val_accuracy did not improve from 0.83889
# Epoch 51/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2327 - accuracy: 0.8883 - val_loss: 0.6610 - val_accuracy: 0.8056
#
# Epoch 00051: val_accuracy did not improve from 0.83889
# Epoch 52/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2396 - accuracy: 0.8943 - val_loss: 0.6596 - val_accuracy: 0.8000
#
# Epoch 00052: val_accuracy did not improve from 0.83889
# Epoch 53/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2462 - accuracy: 0.8866 - val_loss: 0.6603 - val_accuracy: 0.8000
#
# Epoch 00053: val_accuracy did not improve from 0.83889
# Epoch 54/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2545 - accuracy: 0.8840 - val_loss: 0.6640 - val_accuracy: 0.8000
#
# Epoch 00054: val_accuracy did not improve from 0.83889
# Epoch 55/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2372 - accuracy: 0.8909 - val_loss: 0.6697 - val_accuracy: 0.8000
#
# Epoch 00055: val_accuracy did not improve from 0.83889
# Epoch 56/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2289 - accuracy: 0.9003 - val_loss: 0.6710 - val_accuracy: 0.8000
#
# Epoch 00056: val_accuracy did not improve from 0.83889
# Epoch 57/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2378 - accuracy: 0.8969 - val_loss: 0.6699 - val_accuracy: 0.8000
#
# Epoch 00057: val_accuracy did not improve from 0.83889
# Epoch 58/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2301 - accuracy: 0.8943 - val_loss: 0.6698 - val_accuracy: 0.8000
#
# Epoch 00058: val_accuracy did not improve from 0.83889
# Epoch 59/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2447 - accuracy: 0.8883 - val_loss: 0.6610 - val_accuracy: 0.8000
#
# Epoch 00059: val_accuracy did not improve from 0.83889
# Epoch 60/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2304 - accuracy: 0.9098 - val_loss: 0.6581 - val_accuracy: 0.8056
#
# Epoch 00060: val_accuracy did not improve from 0.83889
# Epoch 61/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2270 - accuracy: 0.9098 - val_loss: 0.6550 - val_accuracy: 0.8056
#
# Epoch 00061: val_accuracy did not improve from 0.83889
# Epoch 62/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2287 - accuracy: 0.8978 - val_loss: 0.6527 - val_accuracy: 0.8056
#
# Epoch 00062: val_accuracy did not improve from 0.83889
# Epoch 63/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2346 - accuracy: 0.8943 - val_loss: 0.6491 - val_accuracy: 0.8056
#
# Epoch 00063: val_accuracy did not improve from 0.83889
# Epoch 64/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2338 - accuracy: 0.8892 - val_loss: 0.6448 - val_accuracy: 0.8000
#
# Epoch 00064: val_accuracy did not improve from 0.83889
# Epoch 65/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2211 - accuracy: 0.9064 - val_loss: 0.6428 - val_accuracy: 0.8000
#
# Epoch 00065: val_accuracy did not improve from 0.83889
# Epoch 66/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2195 - accuracy: 0.8986 - val_loss: 0.6449 - val_accuracy: 0.8000
#
# Epoch 00066: val_accuracy did not improve from 0.83889
# Epoch 67/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2412 - accuracy: 0.8918 - val_loss: 0.6456 - val_accuracy: 0.8056
#
# Epoch 00067: val_accuracy did not improve from 0.83889
# Epoch 68/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2360 - accuracy: 0.8969 - val_loss: 0.6471 - val_accuracy: 0.8056
#
# Epoch 00068: val_accuracy did not improve from 0.83889
# Epoch 69/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2280 - accuracy: 0.8952 - val_loss: 0.6536 - val_accuracy: 0.8000
#
# Epoch 00069: val_accuracy did not improve from 0.83889
# Epoch 70/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2364 - accuracy: 0.9098 - val_loss: 0.6539 - val_accuracy: 0.8056
#
# Epoch 00070: val_accuracy did not improve from 0.83889
# Epoch 71/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2147 - accuracy: 0.9064 - val_loss: 0.6540 - val_accuracy: 0.8056
#
# Epoch 00071: val_accuracy did not improve from 0.83889
# Epoch 72/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2291 - accuracy: 0.8918 - val_loss: 0.6545 - val_accuracy: 0.8000
#
# Epoch 00072: val_accuracy did not improve from 0.83889
# Epoch 73/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2360 - accuracy: 0.8892 - val_loss: 0.6576 - val_accuracy: 0.8000
#
# Epoch 00073: val_accuracy did not improve from 0.83889
# Epoch 74/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2362 - accuracy: 0.8875 - val_loss: 0.6608 - val_accuracy: 0.8000
#
# Epoch 00074: val_accuracy did not improve from 0.83889
# Epoch 75/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2347 - accuracy: 0.8943 - val_loss: 0.6655 - val_accuracy: 0.8000
#
# Epoch 00075: val_accuracy did not improve from 0.83889
# Epoch 76/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2166 - accuracy: 0.9089 - val_loss: 0.6603 - val_accuracy: 0.8000
#
# Epoch 00076: val_accuracy did not improve from 0.83889
# Epoch 77/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2346 - accuracy: 0.8969 - val_loss: 0.6656 - val_accuracy: 0.8000
#
# Epoch 00077: val_accuracy did not improve from 0.83889
# Epoch 78/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2282 - accuracy: 0.9081 - val_loss: 0.6629 - val_accuracy: 0.8000
#
# Epoch 00078: val_accuracy did not improve from 0.83889
# Epoch 79/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2295 - accuracy: 0.9021 - val_loss: 0.6614 - val_accuracy: 0.8000
#
# Epoch 00079: val_accuracy did not improve from 0.83889
# Epoch 80/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2408 - accuracy: 0.9021 - val_loss: 0.6658 - val_accuracy: 0.8000
#
# Epoch 00080: val_accuracy did not improve from 0.83889
# Epoch 81/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2383 - accuracy: 0.8943 - val_loss: 0.6627 - val_accuracy: 0.8000
#
# Epoch 00081: val_accuracy did not improve from 0.83889
# Epoch 82/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2521 - accuracy: 0.8935 - val_loss: 0.6577 - val_accuracy: 0.8000
#
# Epoch 00082: val_accuracy did not improve from 0.83889
# Epoch 83/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2321 - accuracy: 0.9081 - val_loss: 0.6552 - val_accuracy: 0.8000
#
# Epoch 00083: val_accuracy did not improve from 0.83889
# Epoch 84/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2366 - accuracy: 0.9029 - val_loss: 0.6586 - val_accuracy: 0.8000
#
# Epoch 00084: val_accuracy did not improve from 0.83889
# Epoch 85/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2335 - accuracy: 0.8995 - val_loss: 0.6581 - val_accuracy: 0.8000
#
# Epoch 00085: val_accuracy did not improve from 0.83889
# Epoch 86/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2189 - accuracy: 0.9072 - val_loss: 0.6523 - val_accuracy: 0.8056
#
# Epoch 00086: val_accuracy did not improve from 0.83889
# Epoch 87/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2289 - accuracy: 0.8995 - val_loss: 0.6536 - val_accuracy: 0.8056
#
# Epoch 00087: val_accuracy did not improve from 0.83889
# Epoch 88/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2353 - accuracy: 0.8978 - val_loss: 0.6568 - val_accuracy: 0.8056
#
# Epoch 00088: val_accuracy did not improve from 0.83889
# Epoch 89/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2188 - accuracy: 0.9012 - val_loss: 0.6579 - val_accuracy: 0.8056
#
# Epoch 00089: val_accuracy did not improve from 0.83889
# Epoch 90/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2356 - accuracy: 0.8986 - val_loss: 0.6515 - val_accuracy: 0.8056
#
# Epoch 00090: val_accuracy did not improve from 0.83889
# Epoch 91/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2368 - accuracy: 0.9055 - val_loss: 0.6467 - val_accuracy: 0.8000
#
# Epoch 00091: val_accuracy did not improve from 0.83889
# Epoch 92/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2216 - accuracy: 0.9072 - val_loss: 0.6455 - val_accuracy: 0.8000
#
# Epoch 00092: val_accuracy did not improve from 0.83889
# Epoch 93/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2293 - accuracy: 0.8960 - val_loss: 0.6473 - val_accuracy: 0.8000
#
# Epoch 00093: val_accuracy did not improve from 0.83889
# Epoch 94/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2365 - accuracy: 0.8909 - val_loss: 0.6470 - val_accuracy: 0.8000
#
# Epoch 00094: val_accuracy did not improve from 0.83889
# Epoch 95/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2313 - accuracy: 0.8935 - val_loss: 0.6437 - val_accuracy: 0.8056
#
# Epoch 00095: val_accuracy did not improve from 0.83889
# Epoch 96/100
# 18/18 [==============================] - 27s 2s/step - loss: 0.2212 - accuracy: 0.9098 - val_loss: 0.6448 - val_accuracy: 0.8056
#
# Epoch 00096: val_accuracy did not improve from 0.83889
# Epoch 97/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2330 - accuracy: 0.8918 - val_loss: 0.6472 - val_accuracy: 0.8056
#
# Epoch 00097: val_accuracy did not improve from 0.83889
# Epoch 98/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2409 - accuracy: 0.8935 - val_loss: 0.6459 - val_accuracy: 0.8056
#
# Epoch 00098: val_accuracy did not improve from 0.83889
# Epoch 99/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2186 - accuracy: 0.9029 - val_loss: 0.6459 - val_accuracy: 0.8056
#
# Epoch 00099: val_accuracy did not improve from 0.83889
# Epoch 100/100
# 18/18 [==============================] - 27s 1s/step - loss: 0.2343 - accuracy: 0.8892 - val_loss: 0.6456 - val_accuracy: 0.8056
#
# Epoch 00100: val_accuracy did not improve from 0.83889

# %%
with open('history.json', 'w') as f:
    json.dump(str(history.history), f)

# %%
history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

# %% [markdown]
# # Prediction

# %%
model.load_weights("/content/drive/MyDrive/Scin Cancer/ISIC 2016/weights.best.hdf5")

# %%
Y_val_pred = model.predict(X_val)

# %%
accuracy_score(np.argmax(Y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.8388888888888889

# %%
Y_pred = model.predict(X_test)

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict_generator(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 100%|██████████| 10/10 [00:59<00:00,  5.91s/it]

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[285  19]
#  [ 52  23]]

# %%
cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[296   8]
#  [ 58  17]]

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.84      0.97      0.90       304\n           1       0.68      0.23      0.34        75\n\n    accuracy                           0.83       379\n   macro avg       0.76      0.60      0.62       379\nweighted avg       0.81      0.83      0.79       379\n'

# %% [markdown]
# ### ROC and AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()
